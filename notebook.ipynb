# %%
print(123)
# Out:
# 123

# %%
# !wget https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/01-agentic-rag/code/rag_helper.py
# Out:
# --2026-06-26 02:44:00--  https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/01-agentic-rag/code/rag_helper.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2134 (2.1K) [text/plain]
# Saving to: ‘rag_helper.py’
#
# rag_helper.py       100%[===================>]   2.08K  --.-KB/s    in 0s
#
# 2026-06-26 02:44:00 (25.4 MB/s) - ‘rag_helper.py’ saved [2134/2134]
# /bin/bash: line 1: wget!: command not found

# %%
# !wget https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/01-agentic-rag/code/ingest.py
# Out:
# --2026-06-26 02:50:44--  https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/01-agentic-rag/code/ingest.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 888 [text/plain]
# Saving to: ‘ingest.py’
#
# ingest.py           100%[===================>]     888  --.-KB/s    in 0s
#
# 2026-06-26 02:50:44 (50.7 MB/s) - ‘ingest.py’ saved [888/888]

# %%
from ingest import load_legal_data

# %%
# Chamada direta sem argumentos
documents = load_legal_data()

# Verificação rápida do resultado
print(f"Carregados {len(documents)} documentos com sucesso!")
# Out:
# Carregados 214 documentos com sucesso!

# %%
documents[0]
# Out:
# {'doc_id': 'D12686',
#  'doc_type': 'Decreto',
#  'doc_number': '12686',
#  'doc_year': '2025',
#  'doc_name': 'Decreto nº 12.686, de 20 de outubro de 2025',
#  'doc_summary': 'Institui a Política Nacional de Educação Especial Inclusiva e a Rede Nacional de Educação Especial Inclusiva.',
#  'article_number': '1',
#  'chunck_id': 'decreto_12686_2025_art_1',
#  'text_original': 'Artigo 1. Fica instituída a Política Nacional de Educação Especial Inclusiva, com a finalidade de garantir o direito à educação em um sistema educacional inclusivo para estudantes com deficiência, com transtorno do espectro autista e com altas habilidades ou superdotação, sem discriminação e com base na igualdade de oportunidades. § 1º A modalidade da educação especial será oferecida de maneira transversal a todos os níveis, etapas e modalidades, com vistas a assegurar recursos e serviços educacionais para apoiar, complementar e suplementar o processo de escolarização. § 2º O estudante com transtorno do espectro autista é considerado pessoa com deficiência para fins da Política Nacional de Educação Especial Inclusiva. § 3º A garantia do sistema educacional inclusivo ocorre por meio da organização do sistema educacional geral, de forma a assegurar que os estudantes que são público da educação especial tenham o direito a ser incluídos em classes e escolas comuns, com o apoio necessário à sua participação, permanência e aprendizagem.',
#  'text_book': '',
#  'text_title': '',
#  'text_chapter': 'Capítulo I - Da política nacional de educação especial inclusiva',
#  'text_section': '',
#  'tags_array': 'PNEEI sistema educacional inclusivo público-alvo direito à educação deficiência TEA altas habilidades',
#  'tags': 'PNEEI, sistema educacional inclusivo, público-alvo, direito à educação, deficiência TEA altas habilidades'}
